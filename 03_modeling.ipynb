# %% [markdown]
# <a href="https://colab.research.google.com/github/aialice-518/aialice-518/blob/main/03_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3. 모델링
#
# 다양한 분류 알고리즘을 적용하고 성능을 비교합니다.
# - 기본 모델: RandomForest, LightGBM, XGBoost
# - 하이퍼파라미터 튜닝: Ray Tune + Optuna
# - AutoML: AutoGluon (Stacking + Bagging)
# - 앙상블: Soft Voting

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

train_data = pd.read_csv('../data/train_processed.csv')
test_raw = pd.read_csv('../data/test_processed.csv')
test_ids = pd.read_csv('../data/test_ids.csv')['ID']

X = train_data.drop('label', axis=1)
y = train_data['label']
print(f"Features: {X.shape[1]}, Samples: {X.shape[0]}")
# Out:
# Features: 45, Samples: 7000

# %% [markdown]
# ## 3.1 기본 모델 비교 (Cross Validation)

# %%
import lightgbm as lgb
import xgboost as xgb

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

models = {
    'RandomForest': RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42),
    'LightGBM': lgb.LGBMClassifier(n_estimators=500, learning_rate=0.05, random_state=42, verbose=-1),
    'XGBoost': xgb.XGBClassifier(n_estimators=500, learning_rate=0.05, random_state=42, use_label_encoder=False, eval_metric='logloss'),
}

results = {}
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=skf, scoring='accuracy')
    results[name] = scores.mean()
    print(f"{name}: {scores.mean():.5f} (±{scores.std():.5f})")
# Out:
# RandomForest: 0.73386 (±0.00534)
# LightGBM: 0.72829 (±0.01035)
# XGBoost: 0.72729 (±0.01165)

# %% [markdown]
# ## 3.2 하이퍼파라미터 튜닝 (Ray Tune + Optuna)
#
# LightGBM과 XGBoost에 대해 Ray Tune 기반 하이퍼파라미터 탐색을 수행합니다.

# %%
import ray
from ray import tune
from ray.tune.search.optuna import OptunaSearch
from ray.tune.schedulers import ASHAScheduler

if ray.is_initialized():
    ray.shutdown()
ray.init(ignore_reinit_error=True)

train_data_ref = ray.put(X)
target_data_ref = ray.put(y)
# Out:
# 2026-04-01 14:24:52,941	INFO worker.py:2014 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265

# %%
import numpy as np
import lightgbm as lgb
import ray

from ray import tune
from ray.air import session
from ray.tune.search.optuna import OptunaSearch
from ray.tune.schedulers import ASHAScheduler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

if ray.is_initialized():
    ray.shutdown()
ray.init(ignore_reinit_error=True)

train_data_ref = ray.put(X)
target_data_ref = ray.put(y)

def train_lgbm_tune(config):
    try:
        X_train = ray.get(train_data_ref)
        y_train = ray.get(target_data_ref)

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        scores = []

        for tr_idx, val_idx in skf.split(X_train, y_train):
            model = lgb.LGBMClassifier(**config, random_state=42, verbose=-1)
            model.fit(X_train.iloc[tr_idx], y_train.iloc[tr_idx])
            pred = model.predict(X_train.iloc[val_idx])
            scores.append(accuracy_score(y_train.iloc[val_idx], pred))

        session.report({"accuracy": float(np.mean(scores))})

    except Exception as e:
        print("Trial failed:", repr(e))
        raise

lgbm_space = {
    'n_estimators': tune.randint(100, 800),
    'learning_rate': tune.loguniform(1e-3, 0.1),
    'num_leaves': tune.randint(20, 100),
    'max_depth': tune.randint(3, 10),
    'min_child_samples': tune.randint(10, 50),
    'subsample': tune.uniform(0.6, 1.0),
    'colsample_bytree': tune.uniform(0.6, 1.0),
    'reg_alpha': tune.loguniform(1e-3, 1.0),
    'reg_lambda': tune.loguniform(1e-3, 1.0),
}

analysis_lgbm = tune.run(
    train_lgbm_tune,
    config=lgbm_space,
    num_samples=5,
    search_alg=OptunaSearch(metric="accuracy", mode="max"),
    scheduler=ASHAScheduler(metric="accuracy", mode="max"),
    verbose=2,
    fail_fast=False,
)

best_config = analysis_lgbm.get_best_config(metric="accuracy", mode="max")
best_trial = analysis_lgbm.get_best_trial(metric="accuracy", mode="max")

print(f"Best LightGBM Accuracy: {best_trial.last_result['accuracy']:.5f}")
print(f"Best Config: {best_config}")
# Out:
# 2026-04-01 14:26:46,255	INFO worker.py:2014 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# [I 2026-04-01 14:26:50,273] A new study created in memory with name: optuna
# +------------------------------------------------------------------------+
# | Configuration for experiment     train_lgbm_tune_2026-04-01_14-26-50   |
# +------------------------------------------------------------------------+
# | Search algorithm                 SearchGenerator                       |
# | Scheduler                        AsyncHyperBandScheduler               |
# | Number of trials                 5                                     |
# +------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_lgbm_tune_2026-04-01_14-26-50
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2026-04-01_14-26-29_635509_68951/artifacts/2026-04-01_14-26-50/train_lgbm_tune_2026-04-01_14-26-50/driver_artifacts`
#
# Trial status: 1 PENDING
# Current time: 2026-04-01 14:27:01. Total running time: 0s
# Logical resource usage: 0/2 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                 status       n_estimators     learning_rate     num_leaves     max_depth     min_child_samples     subsample     colsample_bytree     reg_alpha     reg_lambda |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_lgbm_tune_b4ad88d8   PENDING               543         0.0948291             95             4                    43      0.860624             0.670924       0.34518       0.735425 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial train_lgbm_tune_b4ad88d8 started with configuration:
# +---------------------------------------------------+
# | Trial train_lgbm_tune_b4ad88d8 config             |
# +---------------------------------------------------+
# | colsample_bytree                          0.67092 |
# | learning_rate                             0.09483 |
# | max_depth                                       4 |
# | min_child_samples                              43 |
# | n_estimators                                  543 |
# | num_leaves                                     95 |
# | reg_alpha                                 0.34518 |
# | reg_lambda                                0.73543 |
# | subsample                                 0.86062 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_966c0ee6 started with configuration:
# +---------------------------------------------------+
# | Trial train_lgbm_tune_966c0ee6 config             |
# +---------------------------------------------------+
# | colsample_bytree                          0.83034 |
# | learning_rate                             0.00129 |
# | max_depth                                       6 |
# | min_child_samples                              39 |
# | n_estimators                                  536 |
# | num_leaves                                     25 |
# | reg_alpha                                  0.6913 |
# | reg_lambda                                0.00301 |
# | subsample                                 0.76544 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_b4ad88d8 finished iteration 1 at 2026-04-01 14:27:18. Total running time: 17s
# +---------------------------------------------------+
# | Trial train_lgbm_tune_b4ad88d8 result             |
# +---------------------------------------------------+
# | checkpoint_dir_name                               |
# | time_this_iter_s                          10.9727 |
# | time_total_s                              10.9727 |
# | training_iteration                              1 |
# | accuracy                                  0.72414 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_b4ad88d8 completed after 1 iterations at 2026-04-01 14:27:19. Total running time: 17s
#
# Trial train_lgbm_tune_0afd8725 started with configuration:
# +---------------------------------------------------+
# | Trial train_lgbm_tune_0afd8725 config             |
# +---------------------------------------------------+
# | colsample_bytree                           0.9604 |
# | learning_rate                             0.00247 |
# | max_depth                                       5 |
# | min_child_samples                              22 |
# | n_estimators                                  334 |
# | num_leaves                                     80 |
# | reg_alpha                                  0.3312 |
# | reg_lambda                                0.01184 |
# | subsample                                 0.86023 |
# +---------------------------------------------------+
#
# Trial status: 1 TERMINATED | 2 RUNNING | 1 PENDING
# Current time: 2026-04-01 14:27:32. Total running time: 30s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                 status         n_estimators     learning_rate     num_leaves     max_depth     min_child_samples     subsample     colsample_bytree     reg_alpha     reg_lambda     iter     total time (s)     accuracy |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_lgbm_tune_966c0ee6   RUNNING                 536        0.00129389             25             6                    39      0.765437             0.830341     0.691298      0.00300969                                          |
# | train_lgbm_tune_0afd8725   RUNNING                 334        0.00246872             80             5                    22      0.860227             0.960403     0.331199      0.0118373                                           |
# | train_lgbm_tune_b4ad88d8   TERMINATED              543        0.0948291              95             4                    43      0.860624             0.670924     0.34518       0.735425          1            10.9727     0.724143 |
# | train_lgbm_tune_7cd1ab25   PENDING                 301        0.00398887             74             5                    10      0.70623              0.743381     0.0937805     0.02096                                             |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial train_lgbm_tune_966c0ee6 finished iteration 1 at 2026-04-01 14:27:37. Total running time: 35s
# +---------------------------------------------------+
# | Trial train_lgbm_tune_966c0ee6 result             |
# +---------------------------------------------------+
# | checkpoint_dir_name                               |
# | time_this_iter_s                          19.9384 |
# | time_total_s                              19.9384 |
# | training_iteration                              1 |
# | accuracy                                  0.68971 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_966c0ee6 completed after 1 iterations at 2026-04-01 14:27:37. Total running time: 35s
#
# Trial train_lgbm_tune_0afd8725 finished iteration 1 at 2026-04-01 14:27:43. Total running time: 41s
# +---------------------------------------------------+
# | Trial train_lgbm_tune_0afd8725 result             |
# +---------------------------------------------------+
# | checkpoint_dir_name                               |
# | time_this_iter_s                          14.4107 |
# | time_total_s                              14.4107 |
# | training_iteration                              1 |
# | accuracy                                  0.70029 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_0afd8725 completed after 1 iterations at 2026-04-01 14:27:43. Total running time: 41s
#
# Trial train_lgbm_tune_7cd1ab25 started with configuration:
# +---------------------------------------------------+
# | Trial train_lgbm_tune_7cd1ab25 config             |
# +---------------------------------------------------+
# | colsample_bytree                          0.74338 |
# | learning_rate                             0.00399 |
# | max_depth                                       5 |
# | min_child_samples                              10 |
# | n_estimators                                  301 |
# | num_leaves                                     74 |
# | reg_alpha                                 0.09378 |
# | reg_lambda                                0.02096 |
# | subsample                                 0.70623 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_d0ec8071 started with configuration:
# +---------------------------------------------------+
# | Trial train_lgbm_tune_d0ec8071 config             |
# +---------------------------------------------------+
# | colsample_bytree                          0.91543 |
# | learning_rate                             0.02664 |
# | max_depth                                       4 |
# | min_child_samples                              44 |
# | n_estimators                                  275 |
# | num_leaves                                     77 |
# | reg_alpha                                  0.5755 |
# | reg_lambda                                0.98067 |
# | subsample                                 0.70719 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_7cd1ab25 finished iteration 1 at 2026-04-01 14:27:58. Total running time: 56s
# +---------------------------------------------------+
# | Trial train_lgbm_tune_7cd1ab25 result             |
# +---------------------------------------------------+
# | checkpoint_dir_name                               |
# | time_this_iter_s                          11.8003 |
# | time_total_s                              11.8003 |
# | training_iteration                              1 |
# | accuracy                                  0.71786 |
# +---------------------------------------------------+
#
# Trial train_lgbm_tune_7cd1ab25 completed after 1 iterations at 2026-04-01 14:27:58. Total running time: 56s
# 2026-04-01 14:28:00,745	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_lgbm_tune_2026-04-01_14-26-50' in 0.0096s.
# Trial train_lgbm_tune_d0ec8071 finished iteration 1 at 2026-04-01 14:28:00. Total running time: 58s
# +--------------------------------------------------+
# | Trial train_lgbm_tune_d0ec8071 result            |
# +--------------------------------------------------+
# | checkpoint_dir_name                              |
# | time_this_iter_s                          4.3425 |
# | time_total_s                              4.3425 |
# | training_iteration                             1 |
# | accuracy                                   0.731 |
# +--------------------------------------------------+
#
# Trial train_lgbm_tune_d0ec8071 completed after 1 iterations at 2026-04-01 14:28:00. Total running time: 58s
#
# Trial status: 5 TERMINATED
# Current time: 2026-04-01 14:28:00. Total running time: 58s
# Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                 status         n_estimators     learning_rate     num_leaves     max_depth     min_child_samples     subsample     colsample_bytree     reg_alpha     reg_lambda     iter     total time (s)     accuracy |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_lgbm_tune_b4ad88d8   TERMINATED              543        0.0948291              95             4                    43      0.860624             0.670924     0.34518       0.735425          1            10.9727     0.724143 |
# | train_lgbm_tune_966c0ee6   TERMINATED              536        0.00129389             25             6                    39      0.765437             0.830341     0.691298      0.00300969        1            19.9384     0.689714 |
# | train_lgbm_tune_0afd8725   TERMINATED              334        0.00246872             80             5                    22      0.860227             0.960403     0.331199      0.0118373         1            14.4107     0.700286 |
# | train_lgbm_tune_7cd1ab25   TERMINATED              301        0.00398887             74             5                    10      0.70623              0.743381     0.0937805     0.02096           1            11.8003     0.717857 |
# | train_lgbm_tune_d0ec8071   TERMINATED              275        0.0266428              77             4                    44      0.707189             0.915431     0.575499      0.980674          1             4.3425     0.731    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Best LightGBM Accuracy: 0.73100
# Best Config: {'n_estimators': 275, 'learning_rate': 0.026642847650627795, 'num_leaves': 77, 'max_depth': 4, 'min_child_samples': 44, 'subsample': 0.7071888067407479, 'colsample_bytree': 0.9154309935192317, 'reg_alpha': 0.5754993257783767, 'reg_lambda': 0.9806738717835568}

# %% [markdown]
# ## 3.3 AutoGluon (AutoML)
#
# AutoGluon의 `best_quality` 프리셋으로 자동 스태킹 + 배깅을 적용합니다.
# "왜 이 모델이 더 잘 동작하는가?" → AutoGluon은 다양한 모델을 자동으로 앙상블하여 단일 모델 대비 일반화 성능이 높습니다.

# %%
import torch
from autogluon.tabular import TabularPredictor

USE_GPU = torch.cuda.is_available()
print(f"GPU 사용: {USE_GPU}")

save_path = '../outputs/ag_models'

predictor = TabularPredictor(
    label='label',
    eval_metric='accuracy',
    path=save_path,
    problem_type='binary'
).fit(
    train_data,
    presets='best_quality',
    num_bag_folds=10,
    time_limit=600,
    num_gpus=1 if USE_GPU else 0,
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../outputs/ag_models"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.12.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Mon Feb  2 12:27:57 UTC 2026
# CPU Count:          2
# Pytorch Version:    2.9.1+cu128
# CUDA Version:       CUDA is not available
# Memory Avail:       9.43 GB / 12.67 GB (74.5%)
# Disk Space Avail:   74.63 GB / 107.72 GB (69.3%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 		Context path: "/outputs/ag_models/ds_sub_fit/sub_fit_ho"
# GPU 사용: False
# (_dystack pid=72344) 	0.7433	 = Validation score   (accuracy)
# (_dystack pid=72344) 	52.18s	 = Training   runtime
# (_dystack pid=72344) 	0.21s	 = Validation runtime
# (_dystack pid=72344) Fitting model: LightGBM_BAG_L1 ... Training model for up to 1139.15s of the 1739.34s of remaining time.
# (_dystack pid=72344) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=73079) Running DyStack sub-fit ...
# (_dystack pid=73079) Beginning AutoGluon training ... Time limit = 150s
# (_dystack pid=73079) AutoGluon will save models to "/outputs/ag_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=73079) Train Data Rows:    6222
# (_dystack pid=73079) Train Data Columns: 45
# (_dystack pid=73079) Label Column:       label
# (_dystack pid=73079) Problem Type:       binary
# (_dystack pid=73079) Preprocessing data ...
# (_dystack pid=73079) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=73079) Using Feature Generators to preprocess the data ...
# (_dystack pid=73079) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=73079) 	Available Memory:                    9914.82 MB
# (_dystack pid=73079) 	Train Data (Original)  Memory Usage: 2.14 MB (0.0% of available memory)
# (_dystack pid=73079) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=73079) 	Stage 1 Generators:
# (_dystack pid=73079) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=73079) 			Note: Converting 9 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=73079) 	Stage 2 Generators:
# (_dystack pid=73079) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=73079) 	Stage 3 Generators:
# (_dystack pid=73079) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=73079) 	Stage 4 Generators:
# (_dystack pid=73079) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=73079) 	Stage 5 Generators:
# (_dystack pid=73079) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=73079) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=73079) 		('float', []) : 21 | ['BMI', '시력', '혈청 크레아티닌', '헤모글로빈', '간 효소율', ...]
# (_dystack pid=73079) 		('int', [])   : 24 | ['나이', '키(cm)', '몸무게(kg)', '충치', '공복 혈당', ...]
# (_dystack pid=73079) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=73079) 		('float', [])     : 21 | ['BMI', '시력', '혈청 크레아티닌', '헤모글로빈', '간 효소율', ...]
# (_dystack pid=73079) 		('int', [])       : 15 | ['나이', '키(cm)', '몸무게(kg)', '공복 혈당', '혈압', ...]
# (_dystack pid=73079) 		('int', ['bool']) :  9 | ['충치', '비만여부', '과체중여부', '콜레스테롤위험군', '중성지방고위험군', ...]
# (_dystack pid=73079) 	0.1s = Fit runtime
# (_dystack pid=73079) 	45 features in original data used to generate 45 features in processed data.
# (_dystack pid=73079) 	Train Data (Processed) Memory Usage: 1.76 MB (0.0% of available memory)
# (_dystack pid=73079) Data preprocessing and feature engineering runtime = 0.11s ...
# (_dystack pid=73079) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=73079) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=73079) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=73079) User-specified model hyperparameters to be fit:
# (_dystack pid=73079) {
# (_dystack pid=73079) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=73079) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=73079) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=73079) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=73079) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=73079) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=73079) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=73079) }
# (_dystack pid=73079) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=73079) Fitting 108 L1 models, fit_strategy="sequential" ...
# (_dystack pid=73079) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 99.89s of the 149.87s of remaining time.
# (_dystack pid=73079) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=73079) 	0.7433	 = Validation score   (accuracy)
# (_dystack pid=73079) 	58.7s	 = Training   runtime
# (_dystack pid=73079) 	0.32s	 = Validation runtime
# (_dystack pid=73079) Fitting model: LightGBM_BAG_L1 ... Training model for up to 34.15s of the 84.12s of remaining time.
# (_dystack pid=73079) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_dystack pid=73079) 	0.7398	 = Validation score   (accuracy)
# (_dystack pid=73079) 	66.43s	 = Training   runtime
# (_dystack pid=73079) 	0.17s	 = Validation runtime
# (_dystack pid=73079) Fitting model: WeightedEnsemble_L2 ... Training model for up to 149.88s of the 12.31s of remaining time.
# (_dystack pid=73079) 	Fitting 1 model on all data | Fitting with cpus=2, gpus=0, mem=0.0/6.8 GB
# (_dystack pid=73079) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=73079) 	0.7433	 = Validation score   (accuracy)
# (_dystack pid=73079) 	0.57s	 = Training   runtime
# (_dystack pid=73079) 	0.01s	 = Validation runtime
# (_dystack pid=73079) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=73079) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 11.67s of the 11.42s of remaining time.
# (_dystack pid=73079) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.62%)
# (_ray_fit pid=74671) 	Ran out of time, early stopping on iteration 108. Best iteration is:
# (_ray_fit pid=74671) 	[17]	valid_set's binary_error: 0.276083
# (_ray_fit pid=74796) 	Ran out of time, early stopping on iteration 308. Best iteration is: [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=74796) 	[220]	valid_set's binary_error: 0.236334 [repeated 2x across cluster]
# (_ray_fit pid=74855) 	Ran out of time, early stopping on iteration 142. Best iteration is:
# (_ray_fit pid=74855) 	[26]	valid_set's binary_error: 0.255627
# (_ray_fit pid=74913) 	Ran out of time, early stopping on iteration 302. Best iteration is:
# (_ray_fit pid=74913) 	[33]	valid_set's binary_error: 0.276527
# (_ray_fit pid=75040) 	Ran out of time, early stopping on iteration 147. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=75040) 	[42]	valid_set's binary_error: 0.250804 [repeated 2x across cluster]
# (_ray_fit pid=75165) 	Ran out of time, early stopping on iteration 276. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=75165) 	[35]	valid_set's binary_error: 0.268489 [repeated 2x across cluster]
# (_ray_fit pid=75218) 	Ran out of time, early stopping on iteration 154. Best iteration is:
# (_ray_fit pid=75218) 	[77]	valid_set's binary_error: 0.233119
# (_dystack pid=73079) 	0.7428	 = Validation score   (accuracy)
# (_dystack pid=73079) 	53.2s	 = Training   runtime
# (_dystack pid=73079) 	0.07s	 = Validation runtime
# (_dystack pid=73079) Fitting model: WeightedEnsemble_L3 ... Training model for up to 149.88s of the -62.09s of remaining time.
# (_dystack pid=73079) 	Fitting 1 model on all data | Fitting with cpus=2, gpus=0, mem=0.0/9.1 GB
# (_dystack pid=73079) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=73079) 	0.7433	 = Validation score   (accuracy)
# (_dystack pid=73079) 	0.71s	 = Training   runtime
# (_dystack pid=73079) 	0.01s	 = Validation runtime
# (_dystack pid=73079) AutoGluon training complete, total runtime = 212.86s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1965.6 rows/s (623 batch size)
# (_dystack pid=73079) Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (6222 rows).
# (_dystack pid=73079) 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# (_dystack pid=73079) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/outputs/ag_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=73079) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    LightGBMXT_BAG_L1       0.748072   0.743330    accuracy        3.616846       0.315651   58.700783                 3.616846                0.315651          58.700783            1       True          1
# 1  WeightedEnsemble_L2       0.748072   0.743330    accuracy        3.620207       0.328684   59.270855                 0.003361                0.013034           0.570071            2       True          3
# 2  WeightedEnsemble_L3       0.748072   0.743330    accuracy        3.623154       0.321618   59.406881                 0.006308                0.005968           0.706097            3       True          5
# 3    LightGBMXT_BAG_L2       0.744216   0.742848    accuracy        4.240528       0.559676  178.331043                 0.268518                0.071435          53.201535            2       True          4
# 4      LightGBM_BAG_L1       0.742931   0.739794    accuracy        0.355164       0.172590   66.428725                 0.355164                0.172590          66.428725            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	273s	 = DyStack   runtime |	327s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 327s
# AutoGluon will save models to "/outputs/ag_models"
# Train Data Rows:    7000
# Train Data Columns: 45
# Label Column:       label
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9250.89 MB
# 	Train Data (Original)  Memory Usage: 2.40 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 21 | ['BMI', '시력', '혈청 크레아티닌', '헤모글로빈', '간 효소율', ...]
# 		('int', [])   : 24 | ['나이', '키(cm)', '몸무게(kg)', '충치', '공복 혈당', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 21 | ['BMI', '시력', '혈청 크레아티닌', '헤모글로빈', '간 효소율', ...]
# 		('int', [])       : 16 | ['나이', '키(cm)', '몸무게(kg)', '공복 혈당', '혈압', ...]
# 		('int', ['bool']) :  8 | ['충치', '비만여부', '과체중여부', '콜레스테롤위험군', '중성지방고위험군', ...]
# 	0.2s = Fit runtime
# 	45 features in original data used to generate 45 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.22s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 217.83s of the 326.79s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.7419	 = Validation score   (accuracy)
# 	82.27s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 124.11s of the 233.08s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	0.7433	 = Validation score   (accuracy)
# 	117.27s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 0.89s of the 109.85s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=2, gpus=0, mem=0.0/9.4 GB
# 	0.7376	 = Validation score   (accuracy)
# 	10.4s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 326.82s of the 98.24s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=2, gpus=0, mem=0.0/9.3 GB
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.579, 'RandomForestGini_BAG_L1': 0.368, 'LightGBMXT_BAG_L1': 0.053}
# 	0.7456	 = Validation score   (accuracy)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 98.08s of the 98.04s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	0.7541	 = Validation score   (accuracy)
# 	210.7s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 326.82s of the -122.01s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=2, gpus=0, mem=0.0/9.1 GB
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# 	0.7541	 = Validation score   (accuracy)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 449.26s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 958.5 rows/s (700 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (7000 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/outputs/ag_models")

# %% [markdown]
# ## 3.4 모델 리더보드 확인 및 Soft Voting 앙상블

# %%
lb = predictor.leaderboard(train_data, silent=True)
lb_sorted = lb.sort_values(by='score_val', ascending=False)
base_models = lb_sorted[~lb_sorted['model'].str.contains('WeightedEnsemble')]

top_models = base_models['model'].head(10).tolist()
print("Top 10 모델:")
print(base_models[['model', 'score_val']].head(10))
# Out:
# Top 10 모델:
#                      model  score_val
# 1        LightGBMXT_BAG_L2   0.754143
# 4          LightGBM_BAG_L1   0.743286
# 5        LightGBMXT_BAG_L1   0.741857
# 0  RandomForestGini_BAG_L1   0.737571

# %%
# 상위 3개 모델로 Soft Voting 앙상블
selected_models = top_models[:3]
print(f"앙상블 모델: {selected_models}")

preds = []
for model in selected_models:
    pred_proba = predictor.predict_proba(test_raw, model=model).iloc[:, 1]
    preds.append(pred_proba)

final_proba = sum(preds) / len(preds)

submission = pd.DataFrame({
    'ID': test_ids,
    'label': (final_proba >= 0.5).astype(int)
})
submission.to_csv('../data/result_submission.csv', index=False)
print(f"제출 파일 저장 완료: {submission.shape}")
submission.head()
# Out:
# 앙상블 모델: ['LightGBMXT_BAG_L2', 'LightGBM_BAG_L1', 'LightGBMXT_BAG_L1']
# 제출 파일 저장 완료: (3000, 2)
#           ID  label
# 0  TEST_0000      0
# 1  TEST_0001      0
# 2  TEST_0002      1
# 3  TEST_0003      1
# 4  TEST_0004      0
